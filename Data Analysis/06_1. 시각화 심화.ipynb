# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 막대그래프

# %%
# bar 막대그래프 
plt.bar(range(5),[10,20,30,40,50])
# Out:
# <BarContainer object of 5 artists>

# %%
# 눈금값 설정
plt.bar(range(5),[10,20,30,40,50]) 
plt.xticks(range(5),['a','b','c','d','e'])
# Out:
# ([<matplotlib.axis.XTick at 0x12113a35190>,
#   <matplotlib.axis.XTick at 0x12113a35160>,
#   <matplotlib.axis.XTick at 0x12113be3dc0>,
#   <matplotlib.axis.XTick at 0x12113a66130>,
#   <matplotlib.axis.XTick at 0x12113a748b0>],
#  [Text(0, 0, 'a'),
#   Text(1, 0, 'b'),
#   Text(2, 0, 'c'),
#   Text(3, 0, 'd'),
#   Text(4, 0, 'e')])

# %%
# 스타일 설정
plt.bar(range(5),[10,20,30,40,50], color = 'red', width=0.6, linewidth= 2) 
plt.xticks(range(5),['a','b','c','d','e'])
# Out:
# ([<matplotlib.axis.XTick at 0x12113aa5eb0>,
#   <matplotlib.axis.XTick at 0x12113aa5e80>,
#   <matplotlib.axis.XTick at 0x12113aa55b0>,
#   <matplotlib.axis.XTick at 0x12113ae3190>,
#   <matplotlib.axis.XTick at 0x12113ae38e0>],
#  [Text(0, 0, 'a'),
#   Text(1, 0, 'b'),
#   Text(2, 0, 'c'),
#   Text(3, 0, 'd'),
#   Text(4, 0, 'e')])

# %%
plt.bar(range(5),[10,20,30,40,50], color = ['red','red','blue','orange','green'], width=0.6, linewidth= 2) 
plt.xticks(range(5),['a','b','c','d','e'])
# Out:
# ([<matplotlib.axis.XTick at 0x12113b0c700>,
#   <matplotlib.axis.XTick at 0x12113b0c6d0>,
#   <matplotlib.axis.XTick at 0x12113b06460>,
#   <matplotlib.axis.XTick at 0x12113b40910>,
#   <matplotlib.axis.XTick at 0x12113b40880>],
#  [Text(0, 0, 'a'),
#   Text(1, 0, 'b'),
#   Text(2, 0, 'c'),
#   Text(3, 0, 'd'),
#   Text(4, 0, 'e')])

# %% [markdown]
# ### 박스플롯
# - 이상치를 한 눈에 볼 수 있다.

# %%
x = np.random.normal(2,5,100)
y = np.random.normal(1,6,100)
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12113c242b0>,
#   <matplotlib.lines.Line2D at 0x12113c24580>],
#  'caps': [<matplotlib.lines.Line2D at 0x12113c24850>,
#   <matplotlib.lines.Line2D at 0x12113c24b20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x12113c12fa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12113c24e20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12113c2f130>],
#  'means': []}

# %%
plt.boxplot([x,y])
plt.xticks([1,2],['A','B'])
# Out:
# ([<matplotlib.axis.XTick at 0x12113c5d220>,
#   <matplotlib.axis.XTick at 0x12113c5d1f0>],
#  [Text(1, 0, 'A'), Text(2, 0, 'B')])

# %% [markdown]
# ### 히스토그램
# - 도수분포표를 시각화 한 것

# %%
# 도수분포표
x = np.random.normal(5,10,100)
plt.hist(x)
# Out:
# (array([ 2.,  1.,  8.,  6., 19., 24., 13., 14.,  7.,  6.]),
#  array([-22.65248798, -17.81113756, -12.96978714,  -8.12843672,
#          -3.2870863 ,   1.55426412,   6.39561454,  11.23696496,
#          16.07831538,  20.9196658 ,  25.76101622]),
#  <BarContainer object of 10 artists>)

# %%
# 구간 개수 설정
# 데이터의 분포에 대한 왜곡을 시킬 수 있다. 
# bins는 신중하게 선택을 해야 한다.
# 15~20개 미만 
plt.hist(x, bins=17)
# Out:
# (array([ 1.,  1.,  1.,  3.,  5.,  3.,  5.,  9., 11., 19.,  9.,  7., 11.,
#          3.,  5.,  2.,  5.]),
#  array([-22.65248798, -19.80463479, -16.95678161, -14.10892842,
#         -11.26107523,  -8.41322204,  -5.56536885,  -2.71751566,
#           0.13033753,   2.97819071,   5.8260439 ,   8.67389709,
#          11.52175028,  14.36960347,  17.21745666,  20.06530985,
#          22.91316303,  25.76101622]),
#  <BarContainer object of 17 artists>)

# %%
plt.hist(x, bins=30)
# Out:
# (array([ 1.,  0.,  1.,  1.,  0.,  0.,  3.,  2.,  3.,  2.,  3.,  1.,  6.,
#          5.,  8.,  3., 11., 10.,  5.,  5.,  3.,  5.,  7.,  2.,  1.,  4.,
#          2.,  1.,  2.,  3.]),
#  array([-22.65248798, -21.03870451, -19.42492104, -17.81113756,
#         -16.19735409, -14.58357062, -12.96978714, -11.35600367,
#          -9.7422202 ,  -8.12843672,  -6.51465325,  -4.90086977,
#          -3.2870863 ,  -1.67330283,  -0.05951935,   1.55426412,
#           3.16804759,   4.78183107,   6.39561454,   8.00939801,
#           9.62318149,  11.23696496,  12.85074843,  14.46453191,
#          16.07831538,  17.69209885,  19.30588233,  20.9196658 ,
#          22.53344928,  24.14723275,  25.76101622]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### 히트맵
#
# - 2차원배열로 각 요소의 색상을 시각화는 것
# - 상관계수 표현할 때 등

# %%
data = pd.DataFrame({'DA':[50,70,80],'PG':[10,20,30]},
                   index= ['A','B','C'])
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data, annot=True, fmt='d') # d는 정수 표시 , annot는 박스 대응 데이터 표시
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data, annot=True, fmt='d', linewidth=10,linecolor='white')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data, annot=True, fmt='d', linewidth=10,linecolor='white', cmap='Greys')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - kind =  어떤 그래프를 그릴 것인지 설정할 수 있다.
# - line, bar, hist, box, scatter 등

# %%
df_dw=pd.read_csv('csv/재무제표샘플_대원미디어.csv', encoding='euc-kr')
df_dw
# Out:
#      연도          자산총계         부채총계          자본총계           매출액        영업이익  \
# 0  2016  9.776068e+10  23419492827  7.434119e+10  9.499312e+10  2379822965
# 1  2017  1.043490e+11  23398872100  8.095035e+10  1.207350e+11  6987071352
# 2  2018  1.255730e+11  24027374437  1.015450e+11  1.633750e+11  6412992156
# 3  2019  1.361390e+11  34941404675  1.011980e+11  1.915460e+11  3664066464
# 4  2020  1.446900e+11  35459747467  1.092300e+11  2.662270e+11  7227983716
#
#         당기순이익       부채비율
# 0   480426339  76.044057
# 1  7797097354  77.576381
# 2  4153603488  80.865781
# 3  3181392223  74.334031
# 4  6501208590  75.492644

# %%
df_dw.plot(kind='line', x='연도',y=['영업이익','당기순이익'])
# Out:
# <AxesSubplot:xlabel='연도'>

# %%
df_dw.plot(kind='bar', x='연도',y=['영업이익','당기순이익'],figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='연도'>

# %%
mpg= pd.read_csv('csv/mpg.csv')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
mpg.plot(kind='line', x='year',y=['cty','hwy'],figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ### 다중그래프
# - subplots을 통해서 그래프를 여러 개 그릴 수 있다.
# 1. fig: 도화지의 개념, 그림의 밑바탕을 그리는 것
# 2. 실제 그림을 그리는 것은 axis ax를 통해서 그림을 그린다.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,8))

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=1, ncols=4, figsize=(10,8))

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,8))
# ax로만하고 row, col 지정해주면 알아서 매핑이 된다.
ax[0].plot(mpg['cty'])
ax[1].hist(mpg['model'].value_counts(), facecolor='red')
# Out:
# (array([1., 4., 4., 6., 5., 9., 3., 4., 1., 1.]),
#  array([ 2. ,  2.9,  3.8,  4.7,  5.6,  6.5,  7.4,  8.3,  9.2, 10.1, 11. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 반복문을 통한 다중 그래프 시각화

# %%
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2) #그래프 4가지를 그리겠다. 
plt.figure(figsize=(16,10))
plt.subplots_adjust(wspace= 0.5, hspace= 0.4) #여러 개 그래프가 그려질 것이니 서로 충돌하지 않게 간격 조절

mpg_features = ['manufacturer','model','category','drv']

# 4가지 모두 다 문자열 데이터이므로 count에 대한 시각화를 진행
# sns 카운트 플랏을 그려보겠다.

for idx, feature in enumerate(mpg_features):
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,
                 data= mpg,
                 hue='drv', # 그래프 색상 구분 기준
                 palette = 'pastel' , #색상조절하기
                  ax = ax) 
    ax.set_title(f'{feature} Distribution')
